# %%
# import the plotting libraies
import glob
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
 # import the csv files using pd.read_csv:
#BCMAC-677__training_val_acc_epoch.csv
#BCMAC-678__training_val_acc_epoch.csv
#BCMAC-679__training_val_acc_epoch.csv
#BCMAC-712__training_val_acc_epoch.csv
#BCMAC-713__training_val_acc_epoch.csv
#BCMAC-714__training_val_acc_epoch.csv
#BCMAC-742__training_val_acc_epoch.csv
#BCMAC-743__training_val_acc_epoch.csv
#BCMAC-744__training_val_acc_epoch.csv
#BCMAC-1305__training_val_acc_epoch.csv
#BCMAC-1306__training_val_acc_epoch.csv
#BCMAC-1307__training_val_acc_epoch.csv



run677_csv = pd.read_csv("BCMAC-677__training_val_acc_epoch.csv")
run678_csv = pd.read_csv("BCMAC-678__training_val_acc_epoch.csv")
run679_csv = pd.read_csv("BCMAC-679__training_val_acc_epoch.csv")
run712_csv = pd.read_csv("BCMAC-712__training_val_acc_epoch.csv")
run713_csv = pd.read_csv("BCMAC-713__training_val_acc_epoch.csv")
run714_csv = pd.read_csv("BCMAC-714__training_val_acc_epoch.csv")
run742_csv = pd.read_csv("BCMAC-742__training_val_acc_epoch.csv")
run743_csv = pd.read_csv("BCMAC-743__training_val_acc_epoch.csv")
run744_csv = pd.read_csv("BCMAC-744__training_val_acc_epoch.csv")
run1305_csv = pd.read_csv("BCMAC-1305__training_val_acc_epoch.csv")
run1306_csv = pd.read_csv("BCMAC-1306__training_val_acc_epoch.csv")
run1307_csv = pd.read_csv("BCMAC-1307__training_val_acc_epoch.csv")



sns.set_theme(style="darkgrid", palette="deep")
# seaborn styles are: white, dark, whitegrid, darkgrid, ticks
plt.figure(figsize=(10, 8))
sns.set(font_scale=2.2)


# Plot column 2 (validation accuracy) for each csv file on the same plot
'''plt.plot(run677_csv.iloc[:,2], label="run677")
plt.plot(run678_csv.iloc[:,2], label="run678")
plt.plot(run679_csv.iloc[:,2], label="run679")
plt.plot(run712_csv.iloc[:,2], label="run712")
plt.plot(run713_csv.iloc[:,2], label="run713")
plt.plot(run714_csv.iloc[:,2], label="run714")
plt.plot(run742_csv.iloc[:,2], label="run742")
plt.plot(run743_csv.iloc[:,2], label="run743")
plt.plot(run744_csv.iloc[:,2], label="run744")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Accuracy vs Epochs")
plt.show()'''

# Add a rolling average to the plot
plt.figure(figsize=(10, 8))
sns.set(font_scale=1.2)

# Control
plt.plot(run677_csv.iloc[:,2].rolling(5).mean(), label="run677")
plt.plot(run678_csv.iloc[:,2].rolling(7).mean(), label="run678")
#plt.plot(run679_csv.iloc[:,2].rolling(5).mean(), label="run679")

# Data Augmentation
#plt.plot(run712_csv.iloc[:,2].rolling(5).mean(), label="run712")
#plt.plot(run713_csv.iloc[:,2].rolling(7).mean(), label="run713")
#plt.plot(run714_csv.iloc[:,2].rolling(5).mean(), label="run714")

# Data augmentation 2
#plt.plot(run742_csv.iloc[:,2].rolling(5).mean(), label="run742")
#plt.plot(run743_csv.iloc[:,2].rolling(7).mean(), label="run743")
#plt.plot(run744_csv.iloc[:,2].rolling(5).mean(), label="run744")

# Aggregated
plt.plot(run1305_csv.iloc[:,2].rolling(5).mean(), label="run1305")
plt.plot(run1306_csv.iloc[:,2].rolling(7).mean(), label="run1306")
#plt.plot(run1307_csv.iloc[:,2].rolling(5).mean(), label="run1307")


plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Accuracy vs Epochs")
plt.show()
